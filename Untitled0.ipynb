# %%
from google.colab import files
uploaded = files.upload()   # choose archive.zip from your computer
# Out:
#      <input type="file" id="files-31d6e813-7293-47dc-9c0f-9df63d5dcb8d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31d6e813-7293-47dc-9c0f-9df63d5dcb8d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip -q archive.zip -d dataset

# %%
import os
print(os.listdir("/content/dataset"))
# Out:
# ['animals']

# %%
print(os.listdir("/content/dataset/animals"))
# Out:
# ['dog', 'cat']

# %%
base_dir = "/content/dataset/animals"   # adjust to what you actually see

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

IMG_SIZE = (128, 128)
BATCH_SIZE = 32

train_ds = tf.keras.utils.image_dataset_from_directory(
    base_dir,
    validation_split=0.2,     # 80% train, 20% val
    subset="training",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    base_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

class_names = train_ds.class_names
print("Classes:", class_names)
# Out:
# Found 1000 files belonging to 2 classes.
# Using 800 files for training.
# Found 1000 files belonging to 2 classes.
# Using 200 files for validation.
# Classes: ['cat', 'dog']

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

def build_simple_cnn():
    inputs = layers.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
    x = data_augmentation(inputs)
    x = layers.Rescaling(1./255)(x)

    x = layers.Conv2D(32, 3, activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D()(x)

    x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D()(x)

    x = layers.Conv2D(128, 3, activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dropout(0.5)(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.25)(x)
    outputs = layers.Dense(len(class_names), activation='softmax')(x)

    model = models.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

model = build_simple_cnn()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# ...

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True, monitor='val_accuracy'),
    tf.keras.callbacks.ReduceLROnPlateau(patience=3, factor=0.5, monitor='val_loss')
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.6838 - loss: 0.5712 - val_accuracy: 0.5650 - val_loss: 0.6881 - learning_rate: 0.0010
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.8203 - loss: 0.4262 - val_accuracy: 0.4950 - val_loss: 0.6914 - learning_rate: 0.0010
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.8637 - loss: 0.3044 - val_accuracy: 0.5700 - val_loss: 0.6479 - learning_rate: 0.0010
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9190 - loss: 0.2301 - val_accuracy: 0.5650 - val_loss: 1.0861 - learning_rate: 0.0010
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - accuracy: 0.9337 - loss: 0.1746 - val_accuracy: 0.5650 - val_loss: 1.8205 - learning_rate: 0.0010
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9401 - loss: 0.1800 - val_accuracy: 0.5650 - val_loss: 2.3264 - learning_rate: 0.0010
# Epoch 7/30
# ...

# %%
from google.colab import files
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

uploaded = files.upload()

for fname in uploaded.keys():
    img = Image.open(fname).convert("RGB")
    img = img.resize((128, 128))
    x = np.array(img) / 255.0
    x = np.expand_dims(x, axis=0)

    preds = model.predict(x)[0]
    pred_class = np.argmax(preds)
    class_names = ["cat", "dog"]
    label = class_names[pred_class]
    confidence = preds[pred_class]

    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Prediction: {label} ({confidence*100:.2f}%)")
    plt.show()
# Out:
#      <input type="file" id="files-b30b47e3-1b4d-4405-8768-104ae588c4af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b30b47e3-1b4d-4405-8768-104ae588c4af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
IMG_SIZE_TL = 224
BATCH = 32

train_ds_tl = tf.keras.utils.image_dataset_from_directory(
    base_dir,                  # same base_dir you used before
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(IMG_SIZE_TL, IMG_SIZE_TL),
    batch_size=BATCH
)

val_ds_tl = tf.keras.utils.image_dataset_from_directory(
    base_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(IMG_SIZE_TL, IMG_SIZE_TL),
    batch_size=BATCH
)

class_names = train_ds_tl.class_names
print("Classes:", class_names)
# Out:
# Found 1000 files belonging to 2 classes.
# Using 800 files for training.
# Found 1000 files belonging to 2 classes.
# Using 200 files for validation.
# Classes: ['cat', 'dog']

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

base_model = tf.keras.applications.MobileNetV2(
    include_top=False,
    input_shape=(IMG_SIZE_TL, IMG_SIZE_TL, 3),
    weights="imagenet"
)
base_model.trainable = False   # first stage: freeze
inputs = layers.Input(shape=(IMG_SIZE_TL, IMG_SIZE_TL, 3))

x = data_augmentation(inputs)
x = tf.keras.applications.mobilenet_v2.preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(len(class_names), activation="softmax")(x)

tl_model = models.Model(inputs, outputs)
tl_model.compile(
    optimizer=tf.keras.optimizers.Adam(3e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
tl_model.summary()
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract (Subtract)             │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True, monitor="val_accuracy"),
    tf.keras.callbacks.ReduceLROnPlateau(patience=2, factor=0.5, monitor="val_loss")
]

history_tl = tl_model.fit(
    train_ds_tl,
    validation_data=val_ds_tl,
    epochs=10,
    callbacks=callbacks
)

# fine-tune last layers
base_model.trainable = True
for layer in base_model.layers[:-40]:
    layer.trainable = False

tl_model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

history_ft = tl_model.fit(
    train_ds_tl,
    validation_data=val_ds_tl,
    epochs=10,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.7764 - loss: 0.4602 - val_accuracy: 0.9900 - val_loss: 0.1479 - learning_rate: 3.0000e-04
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9818 - loss: 0.1262 - val_accuracy: 0.9950 - val_loss: 0.0591 - learning_rate: 3.0000e-04
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9884 - loss: 0.0636 - val_accuracy: 0.9950 - val_loss: 0.0370 - learning_rate: 3.0000e-04
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9900 - loss: 0.0377 - val_accuracy: 0.9950 - val_loss: 0.0283 - learning_rate: 3.0000e-04
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9931 - loss: 0.0326 - val_accuracy: 0.9950 - val_loss: 0.0227 - learning_rate: 3.0000e-04
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - accuracy: 0.9829 - loss: 0.0762 - val_accuracy: 0.9950 - val_loss: 0.0064 - learning_rate: 1.0000e-04
# Epoch 2/10
# ...

# %%
from google.colab import files
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

uploaded = files.upload()

for fname in uploaded.keys():
    img = Image.open(fname).convert("RGB")
    img = img.resize((IMG_SIZE_TL, IMG_SIZE_TL))
    x = np.array(img) / 255.0
    x = np.expand_dims(x, axis=0)
    x = tf.keras.applications.mobilenet_v2.preprocess_input(x)

    preds = tl_model.predict(x)[0]
    pred_class = np.argmax(preds)
    label = class_names[pred_class]
    confidence = preds[pred_class]

    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Prediction: {label} ({confidence*100:.2f}%)")
    plt.show()
# Out:
#      <input type="file" id="files-24f1bd24-21c6-4b89-af46-cbd83492cbba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24f1bd24-21c6-4b89-af46-cbd83492cbba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

uploaded = files.upload()

for fname in uploaded.keys():
    img = Image.open(fname).convert("RGB")
    img = img.resize((IMG_SIZE_TL, IMG_SIZE_TL))
    x = np.array(img) / 255.0
    x = np.expand_dims(x, axis=0)
    x = tf.keras.applications.mobilenet_v2.preprocess_input(x)

    preds = tl_model.predict(x)[0]
    pred_class = np.argmax(preds)
    label = class_names[pred_class]
    confidence = preds[pred_class]

    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Prediction: {label} ({confidence*100:.2f}%)")
    plt.show()
# Out:
#      <input type="file" id="files-a4ce562f-55a1-4680-8ccc-ec0039d0e03d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a4ce562f-55a1-4680-8ccc-ec0039d0e03d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

uploaded = files.upload()

for fname in uploaded.keys():
    img = Image.open(fname).convert("RGB")
    img = img.resize((IMG_SIZE_TL, IMG_SIZE_TL))
    x = np.array(img) / 255.0
    x = np.expand_dims(x, axis=0)
    x = tf.keras.applications.mobilenet_v2.preprocess_input(x)

    preds = tl_model.predict(x)[0]
    pred_class = np.argmax(preds)
    label = class_names[pred_class]
    confidence = preds[pred_class]

    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Prediction: {label} ({confidence*100:.2f}%)")
    plt.show()
# Out:
#      <input type="file" id="files-0e51002d-f652-423f-91dd-b7ce32057df5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e51002d-f652-423f-91dd-b7ce32057df5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
base_model.trainable = True
for layer in base_model.layers[:-20]:   # instead of -40
    layer.trainable = False

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2)
])

# %%
from google.colab import files
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

uploaded = files.upload()

for fname in uploaded.keys():
    img = Image.open(fname).convert("RGB")
    img = img.resize((IMG_SIZE_TL, IMG_SIZE_TL))
    x = np.array(img) / 255.0
    x = np.expand_dims(x, axis=0)
    x = tf.keras.applications.mobilenet_v2.preprocess_input(x)

    preds = tl_model.predict(x)[0]
    pred_class = np.argmax(preds)
    label = class_names[pred_class]
    confidence = preds[pred_class]

    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Prediction: {label} ({confidence*100:.2f}%)")
    plt.show()
# Out:
#      <input type="file" id="files-9f73f9f8-da9f-4ca2-9bb2-3d295e6d8980" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f73f9f8-da9f-4ca2-9bb2-3d295e6d8980">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib.pyplot as plt

cats = [img for img, label in train_ds_tl.unbatch().take(200) if label==0]
plt.figure(figsize=(8,8))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(cats[i].numpy().astype("uint8"))
    plt.title("cat")
    plt.axis("off")
plt.show()

# %%
dogs = [img for img, label in train_ds_tl.unbatch().take(200) if label==1]
plt.figure(figsize=(8,8))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(dogs[i].numpy().astype("uint8"))
    plt.title("dog")
    plt.axis("off")
plt.show()

# %%
base_model.trainable = True
for layer in base_model.layers[:-10]:
    layer.trainable = False

# %%
layers.RandomContrast(0.3),
layers.RandomBrightness(0.3),
# Out:
# (<RandomBrightness name=random_brightness, built=False>,)

# %%
from google.colab import files
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Upload image
uploaded = files.upload()

for fname in uploaded.keys():
    img = Image.open(fname).convert("RGB")
    img = img.resize((224, 224))  # same size used for training
    x = np.array(img) / 255.0     # normalize
    x = np.expand_dims(x, axis=0)
    x = tf.keras.applications.mobilenet_v2.preprocess_input(x)

    preds = tl_model.predict(x)[0]
    pred_class = np.argmax(preds)

    # class_names should match your dataset order
    class_names = ["cat", "dog"]

    label = class_names[pred_class]
    confidence = preds[pred_class]

    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Prediction: {label} ({confidence*100:.2f}%)")
    plt.show()
# Out:
#      <input type="file" id="files-95831fa6-22f9-49aa-b4cc-23e5c412bcec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-95831fa6-22f9-49aa-b4cc-23e5c412bcec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Upload image
uploaded = files.upload()

for fname in uploaded.keys():
    img = Image.open(fname).convert("RGB")
    img = img.resize((224, 224))  # same size used for training
    x = np.array(img) / 255.0     # normalize
    x = np.expand_dims(x, axis=0)
    x = tf.keras.applications.mobilenet_v2.preprocess_input(x)

    preds = tl_model.predict(x)[0]
    pred_class = np.argmax(preds)

    # class_names should match your dataset order
    class_names = ["cat", "dog"]

    label = class_names[pred_class]
    confidence = preds[pred_class]

    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Prediction: {label} ({confidence*100:.2f}%)")
    plt.show()
# Out:
#      <input type="file" id="files-a5b374fd-d84c-4e76-a755-5af7b4093a5c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5b374fd-d84c-4e76-a755-5af7b4093a5c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
